# %%
### Verificar versões de livrarias

print(f"Pandas: {pd.__version__}")
print(f"NumPy: {np.__version__}")
print(f"Seaborn: {sns.__version__}")
# Out:
# Pandas: 3.0.5
# NumPy: 2.5.1
# Seaborn: 0.13.2

# %%
#Configuração de ambiente
import warnings

import matplotlib.pyplot as plt
import missingno as msno
import numpy as np
import pandas as pd
import seaborn as sns

#Configuração dos gráficos
sns.set_theme(style="whitegrid")

#Tamanho padrão das figuras
plt.rcParams["figure.figsize"] = (12, 6)

#Exibir até 100 colunas
pd.set_option("display.max_columns", 100)

#Exibir até 100 linhas
pd.set_option("display.max_rows", 100)

#Exibir números com duas casas decimais
pd.set_option("display.float_format", "{:.2f}".format)

#Ignorar avisos não críticos
warnings.filterwarnings("ignore")

# %% [markdown]
# ##Netflix Exploratory Data Analysis (EDA) ##
#
# ##Projeto de Portfólio ##
#
# **Autor: Rodrigo C. Furlan **
#
# ###Objetivos ###
# - Explorar os dados do catálogo da Netflix.
# - Limpar e tratar os dados.
# - Responder perguntas de negócio.
# - Produzir visualizações e insights.
